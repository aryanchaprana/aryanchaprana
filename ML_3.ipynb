# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanchaprana/aryanchaprana/blob/main/ML_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/Social_Network_Ads.csv')
df=df.iloc[:,2:]
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X.shape
# Out:
# (400, 2)

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 350   38           113000          1
# 192   29            43000          0
# 229   42            80000          1
# 80    30            80000          0
# 72    20            23000          0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X_train)
X_trainn=sc.transform(X_train)
X_testt=sc.transform(X_test)
X_trainn

# %%
X_trainn=pd.DataFrame(X_trainn,columns=X_trainn.columns)
X_testt=pd.DataFrame(X_testt,columns=X_testt.columns)

# %%
X_trainn
# Out:
#           Age  EstimatedSalary
# 0   -0.842522         0.130156
# 1    0.041758         0.277702
# 2    0.729530        -1.315791
# 3    1.613809         1.103957
# 4    0.827784        -1.404318
# ..        ...              ...
# 275 -1.333788        -1.286281
# 276 -1.137281        -1.050209
# 277  0.533024         1.841685
# 278  0.140011         0.189175
# 279 -0.547762         0.454757
#
# [280 rows x 2 columns]
