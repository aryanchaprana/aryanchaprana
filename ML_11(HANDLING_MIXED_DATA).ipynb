# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanchaprana/aryanchaprana/blob/main/ML_11(HANDLING_MIXED_DATA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/titanic.csv')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df['Ticket'].nunique()
# Out:
# 681

# %%
df.shape
# Out:
# (891, 4)

# %%
a=df['number'].value_counts().plot.bar()

# %%
df['numberr']=pd.to_numeric(df['number'],errors='coerce',downcast='float')

# %%
df
# Out:
#     Cabin            Ticket number  Survived  numberr
# 0     NaN         A/5 21171      5         0      5.0
# 1     C85          PC 17599      3         1      3.0
# 2     NaN  STON/O2. 3101282      6         1      6.0
# 3    C123            113803      3         1      3.0
# 4     NaN            373450      A         0      NaN
# ..    ...               ...    ...       ...      ...
# 886   NaN            211536      3         0      3.0
# 887   B42            112053      3         1      3.0
# 888   NaN        W./C. 6607      1         0      1.0
# 889  C148            111369      2         1      2.0
# 890   NaN            370376      3         0      3.0
#
# [891 rows x 5 columns]

# %%
df['categ']=np.where(df['numberr'].isnull(),df['number'],np.nan)

# %%
df
# Out:
#     Cabin            Ticket number  Survived  numberr categ
# 0     NaN         A/5 21171      5         0      5.0   NaN
# 1     C85          PC 17599      3         1      3.0   NaN
# 2     NaN  STON/O2. 3101282      6         1      6.0   NaN
# 3    C123            113803      3         1      3.0   NaN
# 4     NaN            373450      A         0      NaN     A
# ..    ...               ...    ...       ...      ...   ...
# 886   NaN            211536      3         0      3.0   NaN
# 887   B42            112053      3         1      3.0   NaN
# 888   NaN        W./C. 6607      1         0      1.0   NaN
# 889  C148            111369      2         1      2.0   NaN
# 890   NaN            370376      3         0      3.0   NaN
#
# [891 rows x 6 columns]

# %%
df['cabin_num']=df['Cabin'].str.extract('(\d+)')
df['cabin_cat']=df['Cabin'].str[0]

# %%
df
# Out:
#     Cabin            Ticket number  Survived  numberr categ cabin_num  \
# 0     NaN         A/5 21171      5         0      5.0   NaN       NaN
# 1     C85          PC 17599      3         1      3.0   NaN        85
# 2     NaN  STON/O2. 3101282      6         1      6.0   NaN       NaN
# 3    C123            113803      3         1      3.0   NaN       123
# 4     NaN            373450      A         0      NaN     A       NaN
# ..    ...               ...    ...       ...      ...   ...       ...
# 886   NaN            211536      3         0      3.0   NaN       NaN
# 887   B42            112053      3         1      3.0   NaN        42
# 888   NaN        W./C. 6607      1         0      1.0   NaN       NaN
# 889  C148            111369      2         1      2.0   NaN       148
# 890   NaN            370376      3         0      3.0   NaN       NaN
#
#     cabin_cat
# 0         NaN
# 1           C
# 2         NaN
# 3           C
# 4         NaN
# ..        ...
# 886       NaN
# ...

# %% [markdown]
# TICKET

# %%
df['ticket_num']=df['Ticket'].apply(lambda x:x.split()[-1])
df['ticket_num']=pd.to_numeric(df['ticket_num'],errors='coerce',downcast='integer')
df['ticket_cat']=df['Ticket'].apply(lambda x:x.split()[0])
df['ticket_cat']=np.where(df['ticket_cat'].str.isdigit(),np.nan,df['ticket_cat'])

# %%
df
# Out:
#     Cabin            Ticket number  Survived  numberr categ cabin_num  \
# 0     NaN         A/5 21171      5         0      5.0   NaN       NaN
# 1     C85          PC 17599      3         1      3.0   NaN        85
# 2     NaN  STON/O2. 3101282      6         1      6.0   NaN       NaN
# 3    C123            113803      3         1      3.0   NaN       123
# 4     NaN            373450      A         0      NaN     A       NaN
# ..    ...               ...    ...       ...      ...   ...       ...
# 886   NaN            211536      3         0      3.0   NaN       NaN
# 887   B42            112053      3         1      3.0   NaN        42
# 888   NaN        W./C. 6607      1         0      1.0   NaN       NaN
# 889  C148            111369      2         1      2.0   NaN       148
# 890   NaN            370376      3         0      3.0   NaN       NaN
#
#     cabin_cat  ticket_num ticket_cat
# 0         NaN     21171.0        A/5
# 1           C     17599.0         PC
# ...
